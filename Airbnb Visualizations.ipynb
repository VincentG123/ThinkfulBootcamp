# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
listings = pd.read_csv('listings2.csv')
calendar = pd.read_csv('months.csv')
listings.price = pd.to_numeric(listings.price, errors='coerce')/100
calendar.price = pd.to_numeric(calendar.price, errors='coerce')/100
calendar_t = calendar.loc[lambda df: calendar['available'] == 't', :]
print(listings)
print(calendar_t)
# Out:
#             id                            listing_url       scrape_id  \
# 0     11813186  https://www.airbnb.com/rooms/11813186  20170602102612
# 1     16133766  https://www.airbnb.com/rooms/16133766  20170602102612
# 2      1740021   https://www.airbnb.com/rooms/1740021  20170602102612
# 3     16926972  https://www.airbnb.com/rooms/16926972  20170602102612
# 4     12814540  https://www.airbnb.com/rooms/12814540  20170602102612
# 5     11847847  https://www.airbnb.com/rooms/11847847  20170602102612
# 6     16926858  https://www.airbnb.com/rooms/16926858  20170602102612
# 7     16927243  https://www.airbnb.com/rooms/16927243  20170602102612
# 8     11870632  https://www.airbnb.com/rooms/11870632  20170602102612
# 9     14977488  https://www.airbnb.com/rooms/14977488  20170602102612
# 10    17417235  https://www.airbnb.com/rooms/17417235  20170602102612
# 11    15532775  https://www.airbnb.com/rooms/15532775  20170602102612
# 12      914617    https://www.airbnb.com/rooms/914617  20170602102612
# 13    10878088  https://www.airbnb.com/rooms/10878088  20170602102612
# 14     7732901   https://www.airbnb.com/rooms/7732901  20170602102612
# 15    13826494  https://www.airbnb.com/rooms/13826494  20170602102612
# 16    15450063  https://www.airbnb.com/rooms/15450063  20170602102612
# 17    16874279  https://www.airbnb.com/rooms/16874279  20170602102612
# 18    12548755  https://www.airbnb.com/rooms/12548755  20170602102612
# 19    17953799  https://www.airbnb.com/rooms/17953799  20170602102612
# 20    11664321  https://www.airbnb.com/rooms/11664321  20170602102612
# 21    12514073  https://www.airbnb.com/rooms/12514073  20170602102612
# 22     3257647   https://www.airbnb.com/rooms/3257647  20170602102612
# 23     1201040   https://www.airbnb.com/rooms/1201040  20170602102612
# 24      914407    https://www.airbnb.com/rooms/914407  20170602102612
# 25     5026237   https://www.airbnb.com/rooms/5026237  20170602102612
# 26    14594476  https://www.airbnb.com/rooms/14594476  20170602102612
# 27    15610091  https://www.airbnb.com/rooms/15610091  20170602102612
# 28     9385410   https://www.airbnb.com/rooms/9385410  20170602102612
# 29    10925522  https://www.airbnb.com/rooms/10925522  20170602102612
# ...        ...                                    ...             ...
# 5277  11813388  https://www.airbnb.com/rooms/11813388  20170602102612
# 5278  18092090  https://www.airbnb.com/rooms/18092090  20170602102612
# 5279   7069992   https://www.airbnb.com/rooms/7069992  20170602102612
# 5280    424500    https://www.airbnb.com/rooms/424500  20170602102612
# 5281  18652475  https://www.airbnb.com/rooms/18652475  20170602102612
# 5282   5268078   https://www.airbnb.com/rooms/5268078  20170602102612
# 5283  12855551  https://www.airbnb.com/rooms/12855551  20170602102612
# 5284  15196410  https://www.airbnb.com/rooms/15196410  20170602102612
# 5285    891786    https://www.airbnb.com/rooms/891786  20170602102612
# 5286  16177259  https://www.airbnb.com/rooms/16177259  20170602102612
# 5287  18897880  https://www.airbnb.com/rooms/18897880  20170602102612
# 5288  17667947  https://www.airbnb.com/rooms/17667947  20170602102612
# 5289  15128985  https://www.airbnb.com/rooms/15128985  20170602102612
# 5290  17160443  https://www.airbnb.com/rooms/17160443  20170602102612
# 5291   1054165   https://www.airbnb.com/rooms/1054165  20170602102612
# 5292  18093143  https://www.airbnb.com/rooms/18093143  20170602102612
# 5293   2413561   https://www.airbnb.com/rooms/2413561  20170602102612
# 5294  12849976  https://www.airbnb.com/rooms/12849976  20170602102612
# 5295  12112674  https://www.airbnb.com/rooms/12112674  20170602102612
# 5296  12832734  https://www.airbnb.com/rooms/12832734  20170602102612
# 5297   5181902   https://www.airbnb.com/rooms/5181902  20170602102612
# 5298  16436630  https://www.airbnb.com/rooms/16436630  20170602102612
# 5299   8556834   https://www.airbnb.com/rooms/8556834  20170602102612
# 5300  15873973  https://www.airbnb.com/rooms/15873973  20170602102612
# 5301  17902750  https://www.airbnb.com/rooms/17902750  20170602102612
# 5302  10430455  https://www.airbnb.com/rooms/10430455  20170602102612
# 5303  11816662  https://www.airbnb.com/rooms/11816662  20170602102612
# 5304  10989680  https://www.airbnb.com/rooms/10989680  20170602102612
# 5305  18565524  https://www.airbnb.com/rooms/18565524  20170602102612
# 5306  18818878  https://www.airbnb.com/rooms/18818878  20170602102612
#
#      last_scraped                                               name  \
# 0      2017-06-02  Fab Garden Dist/Magazine Townhome/Ideal Location!
# 1      2017-06-02                   Garden District Gem - Townhome 2
# 2      2017-06-02                    LARGE I BEDROOM 1BATH IN DUPLEX
# 3      2017-06-02         Charming New Orleans Garden District Stay!
# 4      2017-06-02                NOLA #1 Location St Charles GardenD
# 5      2017-06-02                 Luxury Garden Dist. Carriage House
# 6      2017-06-02              Beautiful Home in the Garden District
# 7      2017-06-02    One Block from Street Car! Can't beat location!
# 8      2017-06-02            Charming Garden District Carriage House
# 9      2017-06-02                   3 Bedroom in the Garden District
# 10     2017-06-02                     Great Garden District home! :)
# 11     2017-06-02                  GARDEN DISTRICT LUXURY EXPERIENCE
# 12     2017-06-02                  Parks-Bowman Mansion: The Library
# 13     2017-06-02  Garden District's awesome view of St. Charles ...
# 14     2017-06-02                Large& Spacious on Magazine Street!
# 15     2017-06-02                          Garden District Apartment
# 16     2017-06-02              Fully Renovated 1890's Carriage House
# 17     2017-06-02            1BD in the heart of the Garden District
# 18     2017-06-02                 Light, Airy Garden District Studio
# 19     2017-06-02  New! Walker Mansion on St Charles Unit 1-Stree...
# 20     2017-06-02                  Irish Channel West Indies Cottage
# 21     2017-06-02                Spacious 2 BD/2 BA Walk to Parades!
# 22     2017-06-02                 Guesthouse W/ Beautiful Courtyard!
# 23     2017-06-02  Garden Distr charmer porch & yard near everyth...
# 24     2017-06-02                 Parks-Bowman Mansion: The Red Room
# 25     2017-06-02                Decorator's House near Magazine St.
# 26     2017-06-02  Relaxing Garden District Apt, Close to Everything
# 27     2017-06-02     Beautiful, Garden District Uptown Home (2 Rms)
# 28     2017-06-02                    Directly on the streetcar line!
# 29     2017-06-02                         Mansion on St. Charles Ave
# ...           ...                                                ...
# 5277   2017-06-02                    1Br/1Ba Unit in Duplex - Uptown
# 5278   2017-06-02          Garden District Guest Suite Near Magazine
# 5279   2017-06-02                 uptown house close to Audubon Park
# 5280   2017-06-02                  Stumble to all things New Orleans
# 5281   2017-06-02  Construction Discount!   Sunny 1BR off Magazin...
# 5282   2017-06-02                Uptown, on the parade route w/prkg.
# 5283   2017-06-02  Cute house uptown! Great for parades/ all star...
# 5284   2017-06-02                               Sixth Ward Sanctuary
# 5285   2017-06-02                 One Bdrm Apt Superbowl rental 2-4
# 5286   2017-06-02              Uptown Near Audubon Park - Sleeps 16!
# 5287   2017-06-02                             Magazine St. Apartment
# 5288   2017-06-02                                New Orleans Shotgun
# 5289   2017-06-02   Uptown Cottage - Walk to the best of New Orleans
# 5290   2017-06-02         Recently Renovated Uptown - Ideal Location
# 5291   2017-06-02                     Audubon Park Craftsman Cottage
# 5292   2017-06-02  NEW! ADORABLE and TOTALLY NOLA home off Magazi...
# 5293   2017-06-02                          Mardi Gras Mambo - Uptown
# 5294   2017-06-02                         Sweet Olive Cottage Uptown
# 5295   2017-06-02                  Uptown Historic Spot: Location!!!
# 5296   2017-06-02                              Uptown & Audubon Park
# 5297   2017-06-02                            Upscale NEW Uptown Home
# 5298   2017-06-02                              Your Mardi Gras spot!
# 5299   2017-06-02  Creole Cottage Steps to Magazine! Sleeps up to 8!
# 5300   2017-06-02  Spacious House, Perfect Location Near Everything!
# 5301   2017-06-02                    Cozy 1 Bedroom With Everything!
# 5302   2017-06-02                                    Big EZ Bungalow
# 5303   2017-06-02                                            Blessed
# 5304   2017-06-02                           Come chillax to the max!
# 5305   2017-06-02                        Lakefront Leisure Apartment
# 5306   2017-06-02                                      Arabi Cottage
#
#                                                 summary  \
# 0     Nestled between famous St. Charles and Magazin...
# 1     Garden District Gem!! This newly renovated, tr...
# 2     VERY NICE MODERN APT IN THE HIPPEST NEIGHBORHO...
# 3     The Sully Mansion is located just one block of...
# 4     Single best location in the city. St Charles n...
# 5     Carriage house (New Orleans-speak for garage a...
# 6     The Sully Mansion is located just one block of...
# 7     The Sully Mansion is located just one block of...
# 8     Experience New Orleans in an authentic carriag...
# 9     This is a beautiful Garden District home! This...
# 10    Comfortable 2 bedroom, 1.5 bath house walking ...
# 11    Beautiful apartment in the heart of the Garden...
# 12    Our biggest bedroom features a beautiful antiq...
# 13    This beautiful 4 bedroom 2 full bathroom apart...
# 14    A fantastic apartment on the second floor of a...
# 15    The apartment place is close to  The Rum House...
# 16    Located on beautiful oak-lined St. Charles Ave...
# 17    My place in Garden District and Magazine Stree...
# 18    Beautiful, naturally lit studio apt, home to a...
# 19    Experience New Orleans in "Grand" style!  This...
# 20    Historic West Indies Cottage located in the Ir...
# 21    Walking distance to all the great bars and res...
# 22    Garden District Guesthouse located on the stre...
# 23    Gorgeous 1860s Greek Revival home w/ modern ki...
# 24    Step back into the 19th century in our Red Roo...
# 25    2 bedroom home, fully furnished in Garden Dist...
# 26    Our quaint, bright and elegant apartment is in...
# 27    Beautiful, two year old home only a few blocks...
# 28    Fully licensed and insured, our beautifully de...
# 29    Stay in a gorgeous Greek Revival mansion on th...
# ...                                                 ...
# 5277  A recently renovated duplex located along Tcho...
# 5278  Your bedroom: The second floor is a private ma...
# 5279  We love our house!  Nice porch for hanging out...
# 5280  Experience Uptown New Orleans.  Audubon Park, ...
# 5281  Construction Special! Lovely, bright 1BR uptow...
# 5282  We are in the heart of it all near great resta...
# 5283  Parades that line up in your front yard...Drui...
# 5284  2 BLOCKS OFF PARADE ROUTE***Our place is close...
# 5285                                                NaN
# 5286  Both sides of a house (6 bedrooms total) in a ...
# 5287  Comfortable rustic two bedroom apartment with ...
# 5288  This Shotgun is located near beautiful Audubon...
# 5289  Our Uptown cottage is tucked behind a tropical...
# 5290  Newly renovated apartment in the heart of upto...
# 5291  This serene and spacious home is surrounded by...
# 5292  NEW LISTING! Our beautiful home is a 1-bedroom...
# 5293  Enjoy walking to the parades in safe Uptown! B...
# 5294  A  Victorian Double Shotgun style home located...
# 5295  Enjoy this classic historic home steps to NOLA...
# 5296  Close to everything - 5 blocks to both Audubon...
# 5297  Beautiful, newly-renovated, professionally-dec...
# 5298  If you are looking for a place for Mardi Gras,...
# 5299  Newly renovated historic 3 bedroom, 2 bath Cre...
# 5300  Quintessential NO house on the Uptown parade r...
# 5301  I offer a completely private room with 1 queen...
# 5302  This home is located in Eastern New Orleans, 2...
# 5303  Escape to beautiful remote Lake Catherine in o...
# 5304  Quite spot in New Orleans east 15 min uber rid...
# 5305  Newly renovated unit in meticulously kept smal...
# 5306  A quiet little cottage tucked away from the pa...
#
#                                                   space  \
# 0     All the charm of New Orleans in this historic ...
# 1                                                   NaN
# 2                                                   NaN
# 3     The Sully Mansion was designed by renowned arc...
# 4     Just a few years ago, my husband & I completed...
# 5                                                   NaN
# 6     The Sully Mansion was designed by renowned arc...
# 7     The Sully Mansion was designed by renowned arc...
# 8                                                   NaN
# 9     This "Oleander House" is a very spacious, luxu...
# 10                                                  NaN
# 11                                                  NaN
# 12    Located in the heart of the Garden District, t...
# 13    The house has a panoramic view of 200 year old...
# 14    Newly renovated, this 2500 s.f. apartment has ...
# 15                                                  NaN
# 16    The space has an airy and bright open kitchen ...
# 17    My place is close to Garden District and Magaz...
# 18    Bright and airy studio apt lived in by an arti...
# 19    Walker Mansion contains 6 separate apartments ...
# 20    One bedroom with a Queen and a large sleeping ...
# 21    Lots of space, walking one block from all the ...
# 22    Garden District Guesthouse located on the stre...
# 23    This gorgeous Greek Revival built in 1860 is f...
# 24    Located in the heart of the Garden District, t...
# 25    This home has been featured in several magazin...
# 26    Our home is uniquely New Orleans, with a front...
# 27    The home is newly built but still holds true t...
# 28    The home was just completely updated two years...
# 29    Stay in a gorgeous Greek Revival mansion on th...
# ...                                                 ...
# 5277                                                NaN
# 5278                                                NaN
# 5279                                                NaN
# 5280  Nestled in charming Uptown New Orleans, this p...
# 5281  Large open front living room and kitchen with ...
# 5282  This is a fun place to stay with two amazing d...
# 5283  This historic house was fully and beautifully ...
# 5284                                                NaN
# 5285  Private one bedroom downstairs apartment in pr...
# 5286  The historical home is both sides of a New Orl...
# 5287  There are a number of amenities in the area in...
# 5288                                                NaN
# 5289  Our home was built a little over 100 years ago...
# 5290  Upstairs apartment with a large open living sp...
# 5291  Beautifully restored Craftsman Cottage facing ...
# 5292  Our space is a traditional New Orleans 1 bedro...
# 5293  Beautiful home with unique furnishings, privat...
# 5294  The home is a Victorian double shotgun that wa...
# 5295  Location, location, location! This is 3 short ...
# 5296  Enjoy a private area separated from the main h...
# 5297                                                NaN
# 5298  *The unit is listed as 'pet free' and never ha...
# 5299  This charming 150-year-old Creole Cottage has ...
# 5300  Downstairs is a light and airy double parlor w...
# 5301                                                NaN
# 5302  2000 sq ft living area which includes 3 bedroo...
# 5303                                                NaN
# 5304                                                NaN
# 5305                                                NaN
# 5306                                                NaN
#
#                                             description experiences_offered  \
# 0     Nestled between famous St. Charles and Magazin...                none
# 1     Garden District Gem!! This newly renovated, tr...                none
# 2     VERY NICE MODERN APT IN THE HIPPEST NEIGHBORHO...                none
# 3     The Sully Mansion is located just one block of...                none
# 4     Single best location in the city. St Charles n...                none
# 5     Carriage house (New Orleans-speak for garage a...                none
# 6     The Sully Mansion is located just one block of...                none
# 7     The Sully Mansion is located just one block of...                none
# 8     Experience New Orleans in an authentic carriag...                none
# 9     This is a beautiful Garden District home! This...                none
# 10    Comfortable 2 bedroom, 1.5 bath house walking ...                none
# 11    Beautiful apartment in the heart of the Garden...                none
# 12    Our biggest bedroom features a beautiful antiq...                none
# 13    This beautiful 4 bedroom 2 full bathroom apart...                none
# 14    A fantastic apartment on the second floor of a...                none
# 15    The apartment place is close to  The Rum House...                none
# 16    Located on beautiful oak-lined St. Charles Ave...                none
# 17    My place in Garden District and Magazine Stree...                none
# 18    Beautiful, naturally lit studio apt, home to a...                none
# 19    Experience New Orleans in "Grand" style!  This...                none
# 20    Historic West Indies Cottage located in the Ir...                none
# 21    Walking distance to all the great bars and res...                none
# 22    Garden District Guesthouse located on the stre...                none
# 23    Gorgeous 1860s Greek Revival home w/ modern ki...                none
# 24    Step back into the 19th century in our Red Roo...                none
# 25    2 bedroom home, fully furnished in Garden Dist...                none
# 26    Our quaint, bright and elegant apartment is in...                none
# 27    Beautiful, two year old home only a few blocks...                none
# 28    Fully licensed and insured, our beautifully de...                none
# 29    Stay in a gorgeous Greek Revival mansion on th...                none
# ...                                                 ...                 ...
# 5277  A recently renovated duplex located along Tcho...                none
# 5278  Your bedroom: The second floor is a private ma...                none
# 5279  We love our house!  Nice porch for hanging out...                none
# 5280  Experience Uptown New Orleans.  Audubon Park, ...                none
# 5281  Construction Special! Lovely, bright 1BR uptow...                none
# 5282  We are in the heart of it all near great resta...                none
# 5283  Parades that line up in your front yard...Drui...                none
# 5284  2 BLOCKS OFF PARADE ROUTE***Our place is close...                none
# 5285  Private one bedroom downstairs apartment in pr...                none
# 5286  Both sides of a house (6 bedrooms total) in a ...                none
# 5287  Comfortable rustic two bedroom apartment with ...                none
# 5288  This Shotgun is located near beautiful Audubon...                none
# 5289  Our Uptown cottage is tucked behind a tropical...                none
# 5290  Newly renovated apartment in the heart of upto...                none
# 5291  This serene and spacious home is surrounded by...                none
# 5292  NEW LISTING! Our beautiful home is a 1-bedroom...                none
# 5293  Enjoy walking to the parades in safe Uptown! B...                none
# 5294  A  Victorian Double Shotgun style home located...                none
# 5295  Enjoy this classic historic home steps to NOLA...                none
# 5296  Close to everything - 5 blocks to both Audubon...                none
# 5297  Beautiful, newly-renovated, professionally-dec...                none
# 5298  If you are looking for a place for Mardi Gras,...                none
# 5299  Newly renovated historic 3 bedroom, 2 bath Cre...                none
# 5300  Quintessential NO house on the Uptown parade r...                none
# 5301  I offer a completely private room with 1 queen...                none
# 5302  This home is located in Eastern New Orleans, 2...                none
# 5303  Escape to beautiful remote Lake Catherine in o...                none
# 5304  Quite spot in New Orleans east 15 min uber rid...                none
# 5305  Newly renovated unit in meticulously kept smal...                none
# 5306  A quiet little cottage tucked away from the pa...                none
#
#                                   neighborhood_overview  \
# 0     Location is everything! Without a doubt, the n...
# 1                                                   NaN
# 2                                                   NaN
# 3     An authentic experience in a Garden District g...
# 4     The gem of NOLA is the Garden District...we ar...
# 5     Our neighborhood is beautiful, full of large, ...
# 6     An authentic experience in a Garden District g...
# 7     An authentic experience in a Garden District g...
# 8     The best of both worlds! The Carriage House is...
# 9     In the heart of the historical Garden District...
# 10                                                  NaN
# 11                                                  NaN
# 12    The Garden District feels like a small town, l...
# 13    The Garden District in a true New Orleans Trad...
# 14    As stated earlier, the apartment resides in th...
# 15                                                  NaN
# 16    A GRAND NEW ORLEANS NEIGHBORHOOD Tradition, op...
# 17                                                  NaN
# 18    This apartment is located in one of the best a...
# 19    Perfect location on St Charles Avenue in the G...
# 20    The most active and desirable part of Uptown N...
# 21    Best neighborhood in New Orleans. World class ...
# 22                                                  NaN
# 23    The Garden District is the best place to stay ...
# 24    The Garden District feels like a small town, l...
# 25    The home is located on a beautiful street line...
# 26    The Garden District is relaxed and comfortable...
# 27    My home is a quick, 4 block walk from Magazine...
# 28    The Garden District is world famous for the be...
# 29    Located in the Beautiful Garden District  on t...
# ...                                                 ...
# 5277  Located along Tchoupitoulas Street in Uptown N...
# 5278  Great location for anyone looking to explore t...
# 5279                                                NaN
# 5280                                                NaN
# 5281  Great, walkable neighborhood with restaurants,...
# 5282  Walking distance to many restaurants of all et...
# 5283  Uptown New Orleans is known for its historic a...
# 5284  This neighborhood is the heart of Uptown livin...
# 5285                                                NaN
# 5286  Safe residential neighborhood with many wonder...
# 5287  Plenty of shopping supporting small businesses...
# 5288                                                NaN
# 5289                                                NaN
# 5290  Prime Location Close to Whole Foods, Walgreens...
# 5291  We are a quiet safe residential neighborhood t...
# 5292  A few of our favorite nearby businesses that a...
# 5293  Safe, safe, safe! Close to great shopping, res...
# 5294  This quiet family-friendly neighborhood is loc...
# 5295  We live next door, and are in love with our ne...
# 5296  Our house is located 5 blocks from Audubon Par...
# 5297                                                NaN
# 5298  Great neighborhood with lots of places within ...
# 5299  Steps from the Mississippi River, you'll hear ...
# 5300                                                NaN
# 5301                                                NaN
# 5302                                                NaN
# 5303                                                NaN
# 5304                                                NaN
# 5305                                                NaN
# 5306                                                NaN
#
#                                                   notes  \
# 0     (1) We have terrific neighbors. Please respect...
# 1                                                   NaN
# 2                                                   NaN
# 3     All rates provided are based on double occupan...
# 4                                                   NaN
# 5                                                   NaN
# 6     All rates provided are based on double occupan...
# 7     All rates provided are based on double occupan...
# 8     There is on-street parking that is first come ...
# 9                                We have a Pack N Play!
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14    The apartment is high up on a tall second floo...
# 15                                                  NaN
# 16    There are 30 local channels plus HBO, Starz & ...
# 17                                                  NaN
# 18    The apartment is on the third floor of a tall,...
# 19    There are 6 apartments in the house with some ...
# 20                                                  NaN
# 21                                     Washer and dryer
# 22                                                  NaN
# 23    Do you know what it means to miss New Orleans?...
# 24                                                  NaN
# 25    Homeowner has a cat, who is not permitted in g...
# 26                                                  NaN
# 27    A welcome packet with pertinent house informat...
# 28    Walking in the Garden District touring the man...
# 29    Note that during Mardi Gras parades pass direc...
# ...                                                 ...
# 5277                                                NaN
# 5278                                                NaN
# 5279                                                NaN
# 5280                                                NaN
# 5281  The construction is concentrated in the back y...
# 5282                                                NaN
# 5283  Guests will have access to a list of our perso...
# 5284  BBQ pit, smoker and fire pit on site and two N...
# 5285                                                NaN
# 5286                                                NaN
# 5287                                                NaN
# 5288                                                NaN
# 5289                                                NaN
# 5290                                                NaN
# 5291  While the house technically sleeps six, becaus...
# 5292                                                NaN
# 5293        Gas grill, 42" TV, DVD player, washer/dryer
# 5294  Parking is easily accessible on the street. A ...
# 5295  All parking is off street parking, but there i...
# 5296                                                NaN
# 5297                                                NaN
# 5298  The area you are in is quite safe and as you w...
# 5299                                                NaN
# 5300  Access to the house may occasionally be restri...
# 5301                                                NaN
# 5302  Sleeping accommodations consist of 1 king size...
# 5303                                                NaN
# 5304                                                NaN
# 5305                                                NaN
# 5306                                                NaN
#
#                                                 transit  \
# 0     So easy! No car? No problem! (1) Walking...two...
# 1                                                   NaN
# 2     THE MAGAZINE BUS AND ST CHARLES STREETCAR ARE ...
# 3     Just one block from the St. Charles streetcar ...
# 4     park in our private, gated and secure driveway...
# 5     Uber and Lyft are both in New Orleans now, and...
# 6     Just one block from the St. Charles streetcar ...
# 7     Just one block from the St. Charles streetcar ...
# 8     The Carriage House is one block from Magazine ...
# 9     Steps to the St. Charles streetcar, or the Mag...
# 10                                                  NaN
# 11                                                  NaN
# 12    We're located three blocks from the St. Charle...
# 13        Steps away from St. Charles Avenue streetcar.
# 14    There is a public bus system on Magazine, and ...
# 15                                                  NaN
# 16    Steps from the St. Charles Avenue Street Car L...
# 17                                                  NaN
# 18    The bus line and sight seeing bus line runs ri...
# 19    Only street parking is available.  It is free ...
# 20    Cab stand one block away and streetcar line is...
# 21    Streetcar is four blocks away on St Charles, b...
# 22                                                  NaN
# 23    One block from the St Charles Street car and a...
# 24    We're located three blocks from the St. Charle...
# 25    Bus on the corner of Magazine Street, and St. ...
# 26    We are only two blocks from St. Charles Avenue...
# 27    The Trolley Car is a 3/4 mile walk, located on...
# 28    The world famous St. Charles Ave streetcar lin...
# 29    The streetcar passed directly in front of the ...
# ...                                                 ...
# 5277                                                NaN
# 5278                                                NaN
# 5279                                                NaN
# 5280                                                NaN
# 5281  The #11 bus is steps away on Magazine Street a...
# 5282  Easy access to both streetcar and bus public t...
# 5283  The Magazine Street bus line is within 2 block...
# 5284  Blocks from the St Charles streetcar and two b...
# 5285                                                NaN
# 5286  Transportation to the French Quarter, Downtown...
# 5287                                                NaN
# 5288  Uber, Taxi Cabs, Bus, Bicycle Rentals and Stre...
# 5289    Magazine Street is one block away and has a bus
# 5290  It is easy to get around. We are Centrally Loc...
# 5291  Two different bus lines are steps away. The Tc...
# 5292  Getting around Magazine Street is easily acces...
# 5293  A bus stop is just around the corner and the h...
# 5294  A walk to Magazine St. is only a block and a h...
# 5295  Options options options. Walking: Again, so cl...
# 5296  Bus Transportation/Stop is only a block away, ...
# 5297                                                NaN
# 5298  Lots of places to walk to but Uber and Lyft ar...
# 5299  If you drive or rent a car we have gated off-s...
# 5300                                                NaN
# 5301                                                NaN
# 5302  Public Transportation 10 mins away.  Host is p...
# 5303                                                NaN
# 5304                                                NaN
# 5305                                                NaN
# 5306  There is a public bus stop 3 blocks away that ...
#
#                                                  access  \
# 0     Right past the kitchen, the side door alley le...
# 1                                                   NaN
# 2                                                   NaN
# 3     Sully Mansion guests have private access to th...
# 4                                           Entire home
# 5     The whole carriage house is yours. Just please...
# 6     Sully Mansion guests have private access to th...
# 7     Sully Mansion guests have private access to th...
# 8     Entrance to the Carriage House is through the ...
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12    Guests will have a private bed and bath, and a...
# 13                                                  NaN
# 14      The entire apartment is available for your use.
# 15                                                  NaN
# 16    Guests will be able to access the entire Carri...
# 17                                                  NaN
# 18    Access to the entire apt and amenities.  It is...
# 19                                                  NaN
# 20                               Access the whole house
# 21    2 bedrooms, 2 bathrooms, kitchen, living room,...
# 22                                                  NaN
# 23    Fully Stocked Kitchen Backyard entertaining Pe...
# 24    Guests will have a private bed and bath, and a...
# 25    Guests have their own entrance. There is a fro...
# 26    You will have access to our front porch, bedro...
# 27    Only registered guests are allowed. Bedrooms u...
# 28                all of the property except the garage
# 29    The apartment opens to a shared courtyard with...
# ...                                                 ...
# 5277                                                NaN
# 5278  Shared spaces: Downstairs is an open floor pla...
# 5279                                                NaN
# 5280                                                NaN
# 5281  You will have one half of a traditional New Or...
# 5282  You will have access to the entire house and a...
# 5283  Guests will have access to all parts of the ho...
# 5284       Our guests have access to a pool and laundry
# 5285                                                NaN
# 5286                                  The entire house.
# 5287  Internet, Television, Amazon Fire TV, Cookware...
# 5288  Wifi, Television, Blue-Tooth Harmon/Kardon Spe...
# 5289  We have some areas locked off for our own priv...
# 5290  Right Side Private entrance with off street pa...
# 5291  The park is your front yard, play in it or enj...
# 5292  Amenities include: HDTV in living room with Ap...
# 5293            Entire house, with exception of closet.
# 5294  Private Porch for guest. Laundry facilities av...
# 5295  Guests will have access to the entire home, se...
# 5296  Guests will be able to enter through the front...
# 5297                                                NaN
# 5298  Guests have entire side unit of shotgun double...
# 5299  You have access to and use of the entire home ...
# 5300  Guests have access to the whole house and are ...
# 5301                                                NaN
# 5302        Large backyard and deck available to guest.
# 5303                                                NaN
# 5304                                                NaN
# 5305                                                NaN
# 5306  You will arrive and have your own access with ...
#
#                                             interaction  \
# 0     We divide our time between our townhouse next ...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     We are available with any and all assistance 2...
# 5     I will be out of town. In an emergency I will ...
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                   We are here as much as you need us!
# 10                                                  NaN
# 11                                                  NaN
# 12    We live and work in our home, so you can see a...
# 13    You are given a key code to the lock box so yo...
# 14    My wife, Tammy and I are here in town most of ...
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18    Whenever I'm not at work, I am available to an...
# 19    We split our time between New Orleans and Fort...
# 20                                                  NaN
# 21    If I am town I will meet guests when they arri...
# 22                                                  NaN
# 23    Text me with any problems or concerns Please r...
# 24    We live and work in our home, so you can see a...
# 25    Homeowner works and lives on premises and is a...
# 26                                                  NaN
# 27    I may be around during your stay (inbox me you...
# 28    I can help with any questions you may have, ju...
# 29    Don't hesitate to call or text for anything du...
# ...                                                 ...
# 5277                                                NaN
# 5278                                                NaN
# 5279                                                NaN
# 5280                                                NaN
# 5281  We are renting our home while we are away on v...
# 5282  Schedule permitting, we love to hang out with ...
# 5283  You will have the entire house to yourselves. ...
# 5284                                                NaN
# 5285                                                NaN
# 5286          I am here as often or little as you need!
# 5287  Hand off keys at time of arrival. Can leave ke...
# 5288  I let the guests decide and set the pace, as t...
# 5289  I am available by text, phone and e-mail.  Our...
# 5290                                  Readily available
# 5291  We live next door and are available if you nee...
# 5292  Property Manager is not on site. In most cases...
# 5293                                           Limited.
# 5294  Owner lives next door and will greet guest for...
# 5295  We live next door and will respect your privac...
# 5296  We'll be available at all times to help guests...
# 5297                                                NaN
# 5298  I live on the other side of the double so you ...
# 5299  We are New Orleans natives and are here for as...
# 5300    We're next door so holler if you need anything!
# 5301                                                NaN
# 5302  Available upon request.  For emergency maybe r...
# 5303                                                NaN
# 5304                                                NaN
# 5305                                                NaN
# 5306                                                NaN
#
#                                             house_rules  \
# 0     Sorry, but... NO first-time Airbnb renters. NO...
# 1                                                   NaN
# 2     THERE IS A NO SMOKING RULE FOR THE ENTIRE PREM...
# 3     You cannot exceed the maximum number of guests...
# 4     No hair coloring or spray tans permitted...Wom...
# 5     No smoking in the house, only on the patio. Th...
# 6     You cannot exceed the maximum number of guests...
# 7     You cannot exceed the maximum number of guests...
# 8     No smoking on property. This includes the cour...
# 9     - NO SMOKING in the house. No bachelor/bachelo...
# 10                                                  NaN
# 11                                                  NaN
# 12    We have two dogs who go in and out as they ple...
# 13    We want you to enjoy New Orleans and our great...
# 14    We have put a lot of time and thought into mak...
# 15                                                  NaN
# 16    New Orleans is all about having a good time, b...
# 17                           No parties and no smoking.
# 18    no outside shoes on the rugs no hanging out on...
# 19    All guests must be 25 or older unless accompan...
# 20                                              No pets
# 21    Don't steal anything and don't party so hard/l...
# 22    The guest house is located in a residential ne...
# 23    Pets are an extra 50 dollars per night per pet...
# 24    We live in a quiet residential neighborhood, s...
# 25    No smoking, no parties, no extra guests. Homeo...
# 26             - Please be respectful of our neighbors.
# 27    - Good hygiene and cleanliness are a must  - P...
# 28    In General: •\tPlease enjoy our complimentary ...
# 29    Please be respectful of other residents in the...
# ...                                                 ...
# 5277  Respect the house and cause no damage.  Also, ...
# 5278    - Must be clean and respectful in shared spaces
# 5279                                                NaN
# 5280  1. No-smoking inside. 2. Check-in after 1 pm &...
# 5281                                                NaN
# 5282                                                NaN
# 5283  Please be respectful of the home we love! Abso...
# 5284  No noise pollution after midnight. No smoking ...
# 5285                             available upon request
# 5286                                                NaN
# 5287  You may have additional guests over before or ...
# 5288                    Well The Golden Rule of course.
# 5289  We want our guests to enjoy themselves thoroug...
# 5290                                                NaN
# 5291  * This is a smoke free environment, there is n...
# 5292  - No smoking indoors or pets ($1,000 fine) No ...
# 5293                               No pets, no smoking.
# 5294  Quiet family-friendly neighborhood, not suitab...
# 5295  We love our neighborhood, and our neighbors. K...
# 5296  No smoking in the house, only on the front por...
# 5297                                                NaN
# 5298  Please enjoy the front porch but be respectful...
# 5299  NO SMOKING and NO PETS, PLEASE! Otherwise, rel...
# 5300  Enjoy restaurants, shopping and the streetcar ...
# 5301  Hey I'm pretty laid back so rules are simple b...
# 5302  Honesty about number of guest staying is requi...
# 5303                                                NaN
# 5304                                                NaN
# 5305                                                NaN
# 5306                                                NaN
#
#                                           thumbnail_url  \
# 0     https://a0.muscache.com/im/pictures/ed66a1dc-5...
# 1                                                   NaN
# 2                                                   NaN
# 3     https://a0.muscache.com/im/pictures/5ef7273c-1...
# 4                                                   NaN
# 5     https://a0.muscache.com/im/pictures/b5f80768-d...
# 6     https://a0.muscache.com/im/pictures/1f78779d-d...
# 7     https://a0.muscache.com/im/pictures/0df27afe-0...
# 8     https://a0.muscache.com/im/pictures/2b92d3da-9...
# 9     https://a0.muscache.com/im/pictures/e8e93067-5...
# 10                                                  NaN
# 11    https://a0.muscache.com/im/pictures/9ed44ea7-a...
# 12    https://a0.muscache.com/im/pictures/81336eab-e...
# 13    https://a0.muscache.com/im/pictures/d0cf8335-3...
# 14    https://a0.muscache.com/im/pictures/6b3858b6-f...
# 15    https://a0.muscache.com/im/pictures/c65a2b5f-f...
# 16    https://a0.muscache.com/im/pictures/70fbbb61-1...
# 17                                                  NaN
# 18    https://a0.muscache.com/im/pictures/7f53645a-c...
# 19    https://a0.muscache.com/im/pictures/bc8c053c-b...
# 20                                                  NaN
# 21                                                  NaN
# 22    https://a0.muscache.com/im/pictures/52273197/d...
# 23    https://a0.muscache.com/im/pictures/77478645/2...
# 24    https://a0.muscache.com/im/pictures/05bc202a-9...
# 25    https://a0.muscache.com/im/pictures/c8a2441f-0...
# 26    https://a0.muscache.com/im/pictures/07bd61eb-5...
# 27    https://a0.muscache.com/im/pictures/63a88a1d-d...
# 28    https://a0.muscache.com/im/pictures/10eecc8d-a...
# 29                                                  NaN
# ...                                                 ...
# 5277  https://a0.muscache.com/im/pictures/3517eb72-a...
# 5278  https://a0.muscache.com/im/pictures/b4ff587c-d...
# 5279  https://a0.muscache.com/im/pictures/89676079/d...
# 5280  https://a0.muscache.com/im/pictures/a4750061-4...
# 5281  https://a0.muscache.com/im/pictures/23983757-7...
# 5282  https://a0.muscache.com/im/pictures/69776366/0...
# 5283  https://a0.muscache.com/im/pictures/ebed580c-4...
# 5284  https://a0.muscache.com/im/pictures/1824d34f-6...
# 5285                                                NaN
# 5286  https://a0.muscache.com/im/pictures/140a0422-b...
# 5287  https://a0.muscache.com/im/pictures/3a99a4d7-4...
# 5288  https://a0.muscache.com/im/pictures/49b87eba-8...
# 5289  https://a0.muscache.com/im/pictures/c0316459-9...
# 5290  https://a0.muscache.com/im/pictures/bed8c870-a...
# 5291  https://a0.muscache.com/im/pictures/73187616/1...
# 5292  https://a0.muscache.com/im/pictures/da064193-a...
# 5293  https://a0.muscache.com/im/pictures/32076400/6...
# 5294  https://a0.muscache.com/im/pictures/ce1f4c78-e...
# 5295  https://a0.muscache.com/im/pictures/c673f6a3-2...
# 5296  https://a0.muscache.com/im/pictures/59801b6b-e...
# 5297  https://a0.muscache.com/im/pictures/64799227/e...
# 5298  https://a0.muscache.com/im/pictures/859cd02a-b...
# 5299  https://a0.muscache.com/im/pictures/108958113/...
# 5300  https://a0.muscache.com/im/pictures/32ae4efb-2...
# 5301  https://a0.muscache.com/im/pictures/7b723835-d...
# 5302  https://a0.muscache.com/im/pictures/1ccad266-7...
# 5303  https://a0.muscache.com/im/pictures/62ea498c-6...
# 5304                                                NaN
# 5305  https://a0.muscache.com/im/pictures/ae1c9cc4-3...
# 5306  https://a0.muscache.com/im/pictures/1f11a554-4...
#
#                                              medium_url  \
# 0     https://a0.muscache.com/im/pictures/ed66a1dc-5...
# 1                                                   NaN
# 2                                                   NaN
# 3     https://a0.muscache.com/im/pictures/5ef7273c-1...
# 4                                                   NaN
# 5     https://a0.muscache.com/im/pictures/b5f80768-d...
# 6     https://a0.muscache.com/im/pictures/1f78779d-d...
# 7     https://a0.muscache.com/im/pictures/0df27afe-0...
# 8     https://a0.muscache.com/im/pictures/2b92d3da-9...
# 9     https://a0.muscache.com/im/pictures/e8e93067-5...
# 10                                                  NaN
# 11    https://a0.muscache.com/im/pictures/9ed44ea7-a...
# 12    https://a0.muscache.com/im/pictures/81336eab-e...
# 13    https://a0.muscache.com/im/pictures/d0cf8335-3...
# 14    https://a0.muscache.com/im/pictures/6b3858b6-f...
# 15    https://a0.muscache.com/im/pictures/c65a2b5f-f...
# 16    https://a0.muscache.com/im/pictures/70fbbb61-1...
# 17                                                  NaN
# ...
# 4     Louisiana State, New Orleans, LA                f              strict
# 5     Louisiana State, New Orleans, LA                f              strict
# 6     Louisiana State, New Orleans, LA                t            flexible
# 7     Louisiana State, New Orleans, LA                t            flexible
# 8     Louisiana State, New Orleans, LA                f              strict
# 9     Louisiana State, New Orleans, LA                f              strict
# 10    Louisiana State, New Orleans, LA                f            flexible
# 11    Louisiana State, New Orleans, LA                f            flexible
# 12    Louisiana State, New Orleans, LA                t            moderate
# 13    Louisiana State, New Orleans, LA                t              strict
# 14    Louisiana State, New Orleans, LA                f              strict
# 15    Louisiana State, New Orleans, LA                f            flexible
# 16    Louisiana State, New Orleans, LA                f              strict
# 17    Louisiana State, New Orleans, LA                f              strict
# 18    Louisiana State, New Orleans, LA                f            moderate
# 19    Louisiana State, New Orleans, LA                t              strict
# 20    Louisiana State, New Orleans, LA                f            flexible
# 21    Louisiana State, New Orleans, LA                f            flexible
# 22    Louisiana State, New Orleans, LA                f              strict
# 23    Louisiana State, New Orleans, LA                f              strict
# 24    Louisiana State, New Orleans, LA                t            moderate
# 25    Louisiana State, New Orleans, LA                f              strict
# 26    Louisiana State, New Orleans, LA                f            moderate
# 27    Louisiana State, New Orleans, LA                t            moderate
# 28    Louisiana State, New Orleans, LA                t              strict
# 29    Louisiana State, New Orleans, LA                f            moderate
# ...                                ...              ...                 ...
# 5277  Louisiana State, New Orleans, LA                f            flexible
# 5278  Louisiana State, New Orleans, LA                f            flexible
# 5279  Louisiana State, New Orleans, LA                f            flexible
# 5280  Louisiana State, New Orleans, LA                t              strict
# 5281  Louisiana State, New Orleans, LA                t            flexible
# 5282  Louisiana State, New Orleans, LA                f              strict
# 5283  Louisiana State, New Orleans, LA                f            moderate
# 5284  Louisiana State, New Orleans, LA                f              strict
# 5285  Louisiana State, New Orleans, LA                f            moderate
# 5286  Louisiana State, New Orleans, LA                t              strict
# 5287  Louisiana State, New Orleans, LA                f            moderate
# 5288  Louisiana State, New Orleans, LA                f              strict
# 5289  Louisiana State, New Orleans, LA                f              strict
# 5290  Louisiana State, New Orleans, LA                f            moderate
# 5291  Louisiana State, New Orleans, LA                f            flexible
# 5292  Louisiana State, New Orleans, LA                t              strict
# 5293  Louisiana State, New Orleans, LA                f            moderate
# 5294  Louisiana State, New Orleans, LA                f              strict
# 5295  Louisiana State, New Orleans, LA                f            moderate
# 5296  Louisiana State, New Orleans, LA                f              strict
# 5297  Louisiana State, New Orleans, LA                f              strict
# 5298  Louisiana State, New Orleans, LA                f              strict
# 5299  Louisiana State, New Orleans, LA                f              strict
# 5300  Louisiana State, New Orleans, LA                t            moderate
# 5301  Louisiana State, New Orleans, LA                t            flexible
# 5302  Louisiana State, New Orleans, LA                f            moderate
# 5303  Louisiana State, New Orleans, LA                f            flexible
# 5304  Louisiana State, New Orleans, LA                f            flexible
# 5305                   Louisiana State                f            flexible
# 5306                   Louisiana State                t              strict
#
#      require_guest_profile_picture require_guest_phone_verification  \
# 0                                f                                f
# 1                                f                                f
# 2                                f                                f
# 3                                t                                t
# 4                                f                                f
# 5                                f                                f
# 6                                t                                t
# 7                                t                                t
# 8                                f                                f
# 9                                f                                f
# 10                               f                                f
# 11                               f                                f
# 12                               f                                f
# 13                               f                                f
# 14                               f                                f
# 15                               f                                f
# 16                               f                                f
# 17                               t                                t
# 18                               f                                f
# 19                               f                                f
# 20                               f                                f
# 21                               f                                f
# 22                               f                                f
# 23                               f                                f
# 24                               f                                f
# 25                               f                                f
# 26                               f                                f
# 27                               f                                f
# 28                               f                                f
# 29                               f                                f
# ...                            ...                              ...
# 5277                             f                                f
# 5278                             f                                f
# 5279                             f                                f
# 5280                             f                                f
# 5281                             f                                f
# 5282                             f                                f
# 5283                             f                                f
# 5284                             f                                f
# 5285                             f                                f
# 5286                             f                                f
# 5287                             f                                f
# 5288                             f                                f
# 5289                             f                                f
# 5290                             f                                f
# 5291                             f                                f
# 5292                             f                                f
# 5293                             f                                f
# 5294                             f                                f
# 5295                             f                                f
# 5296                             f                                f
# 5297                             f                                f
# 5298                             f                                f
# 5299                             f                                f
# 5300                             f                                f
# 5301                             f                                f
# 5302                             f                                f
# 5303                             f                                f
# 5304                             f                                f
# 5305                             f                                f
# 5306                             f                                f
#
#       calculated_host_listings_count  reviews_per_month
# 0                                  2               2.26
# 1                                  5               0.90
# 2                                  1               0.10
# 3                                  9               1.18
# 4                                  1                NaN
# 5                                  1                NaN
# 6                                  9               0.93
# 7                                  9                NaN
# 8                                  1               2.60
# 9                                  3               1.40
# 10                                 1                NaN
# 11                                 1               0.69
# 12                                 3               5.09
# 13                                 2               2.46
# 14                                 1               1.86
# 15                                 1                NaN
# 16                                 2               2.09
# 17                                 1                NaN
# 18                                 1               0.33
# 19                                 2               2.73
# 20                                 1                NaN
# 21                                 1               0.54
# 22                                 1               3.95
# 23                                 1               0.40
# 24                                 3               5.17
# 25                                 1               1.78
# 26                                 1               0.28
# 27                                 1               0.63
# 28                                 2               2.73
# 29                                 3               1.82
# ...                              ...                ...
# 5277                               1               0.98
# 5278                               1                NaN
# 5279                               1               0.04
# 5280                               5               0.80
# 5281                               1                NaN
# 5282                               2               2.04
# 5283                               1               0.25
# 5284                               1               4.17
# 5285                               1                NaN
# 5286                               3               0.54
# 5287                               1                NaN
# 5288                               1               1.56
# 5289                               1               0.88
# 5290                               2               4.34
# 5291                               1               1.55
# 5292                               1               3.00
# 5293                               1                NaN
# 5294                               1               5.31
# 5295                               1               2.67
# 5296                               1               1.60
# 5297                               1               0.19
# 5298                               1               2.75
# 5299                               1               3.02
# 5300                               1               1.30
# 5301                               1               3.53
# 5302                               2               0.56
# 5303                               1               0.14
# 5304                               2                NaN
# 5305                               1                NaN
# 5306                               1               1.00
#
# [5307 rows x 95 columns]
#          listing_id available  price        date month
# 0          11813186         t  344.0  2017-06-02  June
# 2           1740021         t  150.0  2017-06-02  June
# 8          11870632         t   96.0  2017-06-02  June
# 17         16874279         t  145.0  2017-06-02  June
# 22          3257647         t   90.0  2017-06-02  June
# 23          1201040         t  250.0  2017-06-02  June
# 33          2139985         t  128.0  2017-06-02  June
# 34         13396804         t  220.0  2017-06-02  June
# 40         10331478         t  125.0  2017-06-02  June
# 46          8626782         t  135.0  2017-06-02  June
# 50         15144809         t  149.0  2017-06-02  June
# 59         16253394         t  199.0  2017-06-02  June
# 61          1068734         t  275.0  2017-06-02  June
# 63         14202772         t   80.0  2017-06-02  June
# 64         11524421         t   75.0  2017-06-02  June
# 67         16974889         t  200.0  2017-06-02  June
# 68         14466281         t  400.0  2017-06-02  June
# 72         15397773         t   90.0  2017-06-02  June
# 73         10056448         t  172.0  2017-06-02  June
# 74         11526034         t  100.0  2017-06-02  June
# 75         18462091         t   39.0  2017-06-02  June
# 80         11526626         t   75.0  2017-06-02  June
# 81         14197357         t   80.0  2017-06-02  June
# 83         11526906         t   75.0  2017-06-02  June
# 84         11525130         t   75.0  2017-06-02  June
# 85         16930848         t  125.0  2017-06-02  June
# 87         11527041         t   85.0  2017-06-02  June
# 88         14587656         t   85.0  2017-06-02  June
# 89         11526768         t   75.0  2017-06-02  June
# 91         15586559         t  195.0  2017-06-02  June
# ...             ...       ...    ...         ...   ...
# 1936981     4700467         t  711.0  2018-06-01  June
# 1936982     3078371         t  395.0  2018-06-01  June
# 1936983    18446521         t  106.0  2018-06-01  June
# 1936988      831722         t  110.0  2018-06-01  June
# 1936993     9187941         t   80.0  2018-06-01  June
# 1936997    18395486         t  213.0  2018-06-01  June
# 1937001    11759326         t  115.0  2018-06-01  June
# 1937002    15969995         t  319.0  2018-06-01  June
# 1937005      896343         t  229.0  2018-06-01  June
# 1937010    14936664         t  124.0  2018-06-01  June
# 1937012    18311611         t  175.0  2018-06-01  June
# 1937014    13969641         t  400.0  2018-06-01  June
# 1937019    16917176         t  280.0  2018-06-01  June
# 1937021    11986069         t  150.0  2018-06-01  June
# 1937022     5178904         t  156.0  2018-06-01  June
# 1937023    10822746         t  300.0  2018-06-01  June
# 1937024     9691054         t  800.0  2018-06-01  June
# 1937028      424500         t  185.0  2018-06-01  June
# 1937030     5268078         t  100.0  2018-06-01  June
# 1937032    15196410         t  157.0  2018-06-01  June
# 1937033      891786         t  650.0  2018-06-01  June
# 1937034    16177259         t  600.0  2018-06-01  June
# 1937037    15128985         t  250.0  2018-06-01  June
# 1937040    18093143         t  150.0  2018-06-01  June
# 1937044    12832734         t  115.0  2018-06-01  June
# 1937049    17902750         t   77.0  2018-06-01  June
# 1937050    10430455         t  200.0  2018-06-01  June
# 1937051    11816662         t  300.0  2018-06-01  June
# 1937052    10989680         t   50.0  2018-06-01  June
# 1937054    18818878         t  105.0  2018-06-01  June
#
# [1038325 rows x 5 columns]

# %%
price = listings.price.dropna()
sns.distplot(price)
plt.show()

# %%
plt.hist(price, alpha=.3)
sns.rugplot(price)
plt.show()

# %%
sns.boxplot(price)
plt.show()

# %%
sns.violinplot(price)
plt.show()

# %%
sns.kdeplot(price)
plt.show()

# %%
pd.set_option('display.max_columns', None)
listings.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  11813186  https://www.airbnb.com/rooms/11813186  20170602102612
# 1  16133766  https://www.airbnb.com/rooms/16133766  20170602102612
# 2   1740021   https://www.airbnb.com/rooms/1740021  20170602102612
# 3  16926972  https://www.airbnb.com/rooms/16926972  20170602102612
# 4  12814540  https://www.airbnb.com/rooms/12814540  20170602102612
#
#   last_scraped                                               name  \
# 0   2017-06-02  Fab Garden Dist/Magazine Townhome/Ideal Location!
# 1   2017-06-02                   Garden District Gem - Townhome 2
# 2   2017-06-02                    LARGE I BEDROOM 1BATH IN DUPLEX
# 3   2017-06-02         Charming New Orleans Garden District Stay!
# 4   2017-06-02                NOLA #1 Location St Charles GardenD
#
#                                              summary  \
# 0  Nestled between famous St. Charles and Magazin...
# 1  Garden District Gem!! This newly renovated, tr...
# 2  VERY NICE MODERN APT IN THE HIPPEST NEIGHBORHO...
# 3  The Sully Mansion is located just one block of...
# 4  Single best location in the city. St Charles n...
#
#                                                space  \
# 0  All the charm of New Orleans in this historic ...
# 1                                                NaN
# 2                                                NaN
# 3  The Sully Mansion was designed by renowned arc...
# 4  Just a few years ago, my husband & I completed...
#
#                                          description experiences_offered  \
# 0  Nestled between famous St. Charles and Magazin...                none
# 1  Garden District Gem!! This newly renovated, tr...                none
# 2  VERY NICE MODERN APT IN THE HIPPEST NEIGHBORHO...                none
# 3  The Sully Mansion is located just one block of...                none
# 4  Single best location in the city. St Charles n...                none
#
#                                neighborhood_overview  \
# 0  Location is everything! Without a doubt, the n...
# 1                                                NaN
# 2                                                NaN
# 3  An authentic experience in a Garden District g...
# 4  The gem of NOLA is the Garden District...we ar...
#
#                                                notes  \
# 0  (1) We have terrific neighbors. Please respect...
# 1                                                NaN
# 2                                                NaN
# 3  All rates provided are based on double occupan...
# 4                                                NaN
#
#                                              transit  \
# 0  So easy! No car? No problem! (1) Walking...two...
# 1                                                NaN
# 2  THE MAGAZINE BUS AND ST CHARLES STREETCAR ARE ...
# 3  Just one block from the St. Charles streetcar ...
# 4  park in our private, gated and secure driveway...
#
#                                               access  \
# 0  Right past the kitchen, the side door alley le...
# 1                                                NaN
# 2                                                NaN
# 3  Sully Mansion guests have private access to th...
# 4                                        Entire home
#
#                                          interaction  \
# 0  We divide our time between our townhouse next ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  We are available with any and all assistance 2...
#
#                                          house_rules  \
# 0  Sorry, but... NO first-time Airbnb renters. NO...
# 1                                                NaN
# 2  THERE IS A NO SMOKING RULE FOR THE ENTIRE PREM...
# 3  You cannot exceed the maximum number of guests...
# 4  No hair coloring or spray tans permitted...Wom...
#
#                                        thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/ed66a1dc-5...
# 1                                                NaN
# 2                                                NaN
# 3  https://a0.muscache.com/im/pictures/5ef7273c-1...
# 4                                                NaN
#
#                                           medium_url  \
# 0  https://a0.muscache.com/im/pictures/ed66a1dc-5...
# 1                                                NaN
# 2                                                NaN
# 3  https://a0.muscache.com/im/pictures/5ef7273c-1...
# 4                                                NaN
#
#                                          picture_url  \
# 0  https://a0.muscache.com/im/pictures/ed66a1dc-5...
# 1  https://a0.muscache.com/im/pictures/94e8660b-d...
# 2  https://a0.muscache.com/im/pictures/24707615/0...
# 3  https://a0.muscache.com/im/pictures/5ef7273c-1...
# 4  https://a0.muscache.com/im/pictures/9ec7fb29-8...
#
#                                       xl_picture_url   host_id  \
# 0  https://a0.muscache.com/im/pictures/ed66a1dc-5...  46417812
# 1                                                NaN  23621291
# 2                                                NaN   9161662
# 3  https://a0.muscache.com/im/pictures/5ef7273c-1...   2851267
# 4                                                NaN  69889161
#
#                                      host_url host_name  host_since  \
# 0  https://www.airbnb.com/users/show/46417812       Jan  2015-10-12
# 1  https://www.airbnb.com/users/show/23621291      Ravi  2014-11-11
# 2   https://www.airbnb.com/users/show/9161662      Jack  2013-10-01
# 3   https://www.airbnb.com/users/show/2851267   Melinda  2012-07-06
# 4  https://www.airbnb.com/users/show/69889161     Randy  2016-05-01
#
#                            host_location  \
# 0  New Orleans, Louisiana, United States
# 1                                     US
# 2  New Orleans, Louisiana, United States
# 3  New Orleans, Louisiana, United States
# 4  New Orleans, Louisiana, United States
#
#                                           host_about  host_response_time  \
# 0  Creative thinker, project-developer, people-me...  within a few hours
# 1                                                NaN        within a day
# 2   I AM A NATIVE NEW ORLEANIAN, BUT HAVE LIVED I...        within a day
# 3    \r\nI love the idea of creating magical expe...      within an hour
# 4                 Married with 3 sons...entrepreneur      within an hour
#
#   host_response_rate  host_acceptance_rate host_is_superhost  \
# 0               100%                   NaN                 t
# 1               100%                   NaN                 f
# 2                50%                   NaN                 f
# 3               100%                   NaN                 f
# 4               100%                   NaN                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/8896e2bb-5...
# 1  https://a0.muscache.com/im/users/23621291/prof...
# 2  https://a0.muscache.com/im/users/9161662/profi...
# 3  https://a0.muscache.com/im/users/2851267/profi...
# 4  https://a0.muscache.com/im/pictures/17f2d5a3-6...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/8896e2bb-5...    Garden District
# 1  https://a0.muscache.com/im/users/23621291/prof...              Milan
# 2  https://a0.muscache.com/im/users/9161662/profi...    Garden District
# 3  https://a0.muscache.com/im/users/2851267/profi...    Garden District
# 4  https://a0.muscache.com/im/pictures/17f2d5a3-6...    Garden District
#
#    host_listings_count  host_total_listings_count  \
# 0                  2.0                        2.0
# 1                  6.0                        6.0
# 2                  1.0                        1.0
# 3                  9.0                        9.0
# 4                  1.0                        1.0
#
#                                   host_verifications host_has_profile_pic  \
# 0               ['email', 'phone', 'reviews', 'kba']                    t
# 1  ['email', 'phone', 'google', 'reviews', 'jumio...                    t
# 2               ['email', 'phone', 'reviews', 'kba']                    t
# 3          ['email', 'phone', 'facebook', 'reviews']                    t
# 4  ['email', 'phone', 'google', 'kba', 'work_email']                    t
#
#   host_identity_verified                                             street  \
# 0                      t  Garden District, New Orleans, LA 70115, United...
# 1                      t  Garden District, New Orleans, LA 70130, United...
# 2                      t  Garden District, New Orleans, LA 70130, United...
# 3                      f  Garden District, New Orleans, LA 70130, United...
# 4                      t  Garden District, New Orleans, LA 70130, United...
#
#      neighbourhood neighbourhood_cleansed  neighbourhood_group_cleansed  \
# 0  Garden District        Garden District                           NaN
# 1  Garden District        Garden District                           NaN
# 2  Garden District        Garden District                           NaN
# 3  Garden District        Garden District                           NaN
# 4  Garden District        Garden District                           NaN
#
#           city state zipcode       market   smart_location country_code  \
# 0  New Orleans    LA   70115  New Orleans  New Orleans, LA           US
# 1  New Orleans    LA   70130  New Orleans  New Orleans, LA           US
# 2  New Orleans    LA   70130  New Orleans  New Orleans, LA           US
# 3  New Orleans    LA   70130  New Orleans  New Orleans, LA           US
# 4  New Orleans    LA   70130  New Orleans  New Orleans, LA           US
#
#          country   latitude  longitude is_location_exact    property_type  \
# 0  United States  29.925688 -90.086373                 t        Townhouse
# 1  United States  29.926893 -90.082432                 t        Townhouse
# 2  United States  29.929513 -90.082265                 t        Apartment
# 3  United States  29.929507 -90.085184                 t  Bed & Breakfast
# 4  United States  29.929731 -90.085264                 t            House
#
#          room_type  accommodates  bathrooms  bedrooms  beds  bed_type  \
# 0  Entire home/apt             8        2.0       3.0   4.0  Real Bed
# 1  Entire home/apt            10        3.0       5.0   5.0  Real Bed
# 2  Entire home/apt             4        1.0       1.0   2.0  Real Bed
# 3     Private room             3        1.0       1.0   2.0  Real Bed
# 4  Entire home/apt             6        3.5       3.0   4.0  Real Bed
#
#                                            amenities  square_feet  price  \
# 0  {"Cable TV","Wireless Internet","Air condition...          NaN  294.0
# 1  {TV,"Cable TV",Internet,"Wireless Internet","A...          NaN  650.0
# 2  {"Cable TV","Wireless Internet","Air condition...          NaN  110.0
# 3  {TV,"Wireless Internet","Air conditioning",Bre...          NaN  241.0
# 4  {TV,"Cable TV",Internet,"Wireless Internet","A...          NaN  695.0
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0          NaN           NaN          $500.00      $150.00                6
# 1          NaN           NaN              NaN          NaN                1
# 2          NaN           NaN          $500.00       $50.00                4
# 3          NaN           NaN              NaN          NaN                1
# 4          NaN           NaN        $1,500.00      $350.00                6
#
#   extra_people  minimum_nights  maximum_nights calendar_updated  \
# 0       $50.00               3              28      2 weeks ago
# 1        $0.00               3            1125            today
# 2      $100.00               2            1125            today
# 3        $0.00               2            1125            today
# 4       $75.00               3            1125            today
#
#    has_availability  availability_30  availability_60  availability_90  \
# 0               NaN               24               54               84
# 1               NaN               25               50               80
# 2               NaN               27               47               70
# 3               NaN               20               42               67
# 4               NaN               11               39               69
#
#    availability_365 calendar_last_scraped  number_of_reviews first_review  \
# 0               130            2017-06-02                 31   2016-04-17
# 1               319            2017-06-02                  2   2017-03-28
# 2               341            2017-06-02                  3   2015-01-20
# 3               301            2017-06-02                  2   2017-04-13
# 4               307            2017-06-02                  0          NaN
#
#   last_review  review_scores_rating  review_scores_accuracy  \
# 0  2017-05-15                  99.0                    10.0
# 1  2017-04-09                 100.0                    10.0
# 2  2016-04-20                 100.0                    10.0
# 3  2017-05-08                 100.0                    10.0
# 4         NaN                   NaN                     NaN
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       10.0                   10.0
# 1                       10.0                   10.0
# 2                       10.0                   10.0
# 3                       10.0                   10.0
# 4                        NaN                    NaN
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                 10.0
# 1                         10.0                    10.0                 10.0
# 2                         10.0                    10.0                  9.0
# 3                         10.0                    10.0                  9.0
# 4                          NaN                     NaN                  NaN
#
#   requires_license                    license  \
# 0                t  City registration pending
# 1                t                17STR-03701
# 2                t  City registration pending
# 3                t                     145754
# 4                t  City registration pending
#
#                  jurisdiction_names instant_bookable cancellation_policy  \
# 0  Louisiana State, New Orleans, LA                f              strict
# 1  Louisiana State, New Orleans, LA                f            flexible
# 2  Louisiana State, New Orleans, LA                f              strict
# 3  Louisiana State, New Orleans, LA                t            flexible
# 4  Louisiana State, New Orleans, LA                f              strict
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             t                                t
# 4                             f                                f
#
#    calculated_host_listings_count  reviews_per_month
# 0                               2               2.26
# 1                               5               0.90
# 2                               1               0.10
# 3                               9               1.18
# 4                               1                NaN

# %%
sns.lmplot('latitude', 'longitude', data=listings, fit_reg=False, size=10, aspect=1)
plt.show()

# %%
plt.figure(figsize=(12,12))
sns.kdeplot(listings.latitude.dropna(), listings.longitude.dropna())
plt.show()

# %%
sns.jointplot('latitude', 'longitude', data=listings, size=10, ratio=6)
plt.show()

# %%
sns.jointplot(x=listings.latitude.dropna(), y=listings.longitude.dropna(), kind="hex", color="k", size=10, ratio=6)
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.swarmplot(x="neighbourhood", y="price", data=listings)
plt.xticks(rotation=90)
plt.show()

# %%
g = sns.factorplot("neighbourhood", "price", data=listings, kind="bar", size=6, aspect=2, palette="muted", legend=False)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.stripplot(x="neighbourhood", y="price", data=listings)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.boxplot(x="neighbourhood", y="price", data=listings)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.violinplot(x="neighbourhood", y="price", data=listings)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.barplot(x="neighbourhood", y="price", data=listings)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.pointplot(x="neighbourhood", y="price", data=listings,
              markers=["^", "o"], linestyles=["-", "--"])
plt.xticks(rotation=90)
plt.show()
