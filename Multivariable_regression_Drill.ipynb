# %%
import numpy as np
import pandas as pd
import scipy
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
nyc_crime = pd.read_excel('nyc_crime.xls')

# %%
nyc_crime.head()
# Out:
#                              Table 8  Unnamed: 1      Unnamed: 2  \
# 0                           NEW YORK         NaN             NaN
# 1  Offenses Known to Law Enforcement         NaN             NaN
# 2                      by City, 2013         NaN             NaN
# 3                               City  Population  Violent\ncrime
# 4                      Adams Village        1861               0
#
#                                Unnamed: 3                    Unnamed: 4  \
# 0                                     NaN                           NaN
# 1                                     NaN                           NaN
# 2                                     NaN                           NaN
# 3  Murder and\nnonnegligent\nmanslaughter  Rape\n(revised\ndefinition)1
# 4                                       0                           NaN
#
#                     Unnamed: 5 Unnamed: 6           Unnamed: 7  \
# 0                          NaN        NaN                  NaN
# 1                                     NaN                  NaN
# 2                          NaN        NaN                  NaN
# 3  Rape\n(legacy\ndefinition)2    Robbery  Aggravated\nassault
# 4                            0          0                    0
#
#         Unnamed: 8 Unnamed: 9      Unnamed: 10            Unnamed: 11  \
# 0              NaN        NaN              NaN                    NaN
# 1              NaN        NaN              NaN                    NaN
# 2              NaN        NaN              NaN                    NaN
# 3  Property\ncrime   Burglary  Larceny-\ntheft  Motor\nvehicle\ntheft
# 4               12          2               10                      0
#
#   Unnamed: 12
# 0         NaN
# 1         NaN
# 2         NaN
# 3      Arson3
# 4           0

# %%
nyc_crime.columns = nyc_crime.iloc[3]

# %%
nyc_crime.head()
# Out:
# 3                               City  Population  Violent\ncrime  \
# 0                           NEW YORK         NaN             NaN
# 1  Offenses Known to Law Enforcement         NaN             NaN
# 2                      by City, 2013         NaN             NaN
# 3                               City  Population  Violent\ncrime
# 4                      Adams Village        1861               0
#
# 3  Murder and\nnonnegligent\nmanslaughter  Rape\n(revised\ndefinition)1  \
# 0                                     NaN                           NaN
# 1                                     NaN                           NaN
# 2                                     NaN                           NaN
# 3  Murder and\nnonnegligent\nmanslaughter  Rape\n(revised\ndefinition)1
# 4                                       0                           NaN
#
# 3  Rape\n(legacy\ndefinition)2  Robbery  Aggravated\nassault  Property\ncrime  \
# 0                          NaN      NaN                  NaN              NaN
# 1                                   NaN                  NaN              NaN
# 2                          NaN      NaN                  NaN              NaN
# 3  Rape\n(legacy\ndefinition)2  Robbery  Aggravated\nassault  Property\ncrime
# 4                            0        0                    0               12
#
# 3  Burglary  Larceny-\ntheft  Motor\nvehicle\ntheft  Arson3
# 0       NaN              NaN                    NaN     NaN
# 1       NaN              NaN                    NaN     NaN
# 2       NaN              NaN                    NaN     NaN
# 3  Burglary  Larceny-\ntheft  Motor\nvehicle\ntheft  Arson3
# 4         2               10                      0       0

# %%
nyc_crime = nyc_crime.drop(nyc_crime.index[:4])
nyc_crime.head()
# Out:
# 3                      City Population Violent\ncrime  \
# 4             Adams Village       1861              0
# 5  Addison Town and Village       2577              3
# 6             Akron Village       2846              3
# 7                    Albany      97956            791
# 8            Albion Village       6388             23
#
# 3 Murder and\nnonnegligent\nmanslaughter Rape\n(revised\ndefinition)1  \
# 4                                      0                          NaN
# 5                                      0                          NaN
# 6                                      0                          NaN
# 7                                      8                          NaN
# 8                                      0                          NaN
#
# 3 Rape\n(legacy\ndefinition)2 Robbery Aggravated\nassault Property\ncrime  \
# 4                           0       0                   0              12
# 5                           0       0                   3              24
# 6                           0       0                   3              16
# 7                          30     227                 526            4090
# 8                           3       4                  16             223
#
# 3 Burglary Larceny-\ntheft Motor\nvehicle\ntheft Arson3
# 4        2              10                     0      0
# 5        3              20                     1      0
# 6        1              15                     0      0
# 7      705            3243                   142    NaN
# 8       53             165                     5    NaN

# %%
nyc_crime = nyc_crime.reset_index(drop=True)
nyc_crime.index.name = None

# %%
nyc_crime.head()
# Out:
# 3                      City Population Violent\ncrime  \
# 0             Adams Village       1861              0
# 1  Addison Town and Village       2577              3
# 2             Akron Village       2846              3
# 3                    Albany      97956            791
# 4            Albion Village       6388             23
#
# 3 Murder and\nnonnegligent\nmanslaughter Rape\n(revised\ndefinition)1  \
# 0                                      0                          NaN
# 1                                      0                          NaN
# 2                                      0                          NaN
# 3                                      8                          NaN
# 4                                      0                          NaN
#
# 3 Rape\n(legacy\ndefinition)2 Robbery Aggravated\nassault Property\ncrime  \
# 0                           0       0                   0              12
# 1                           0       0                   3              24
# 2                           0       0                   3              16
# 3                          30     227                 526            4090
# 4                           3       4                  16             223
#
# 3 Burglary Larceny-\ntheft Motor\nvehicle\ntheft Arson3
# 0        2              10                     0      0
# 1        3              20                     1      0
# 2        1              15                     0      0
# 3      705            3243                   142    NaN
# 4       53             165                     5    NaN

# %%
nyc_crime['Population_Squared'] = nyc_crime['Population']*nyc_crime['Population']

# %%
nyc_crime.head()
# Out:
# 3                      City Population Violent\ncrime  \
# 0             Adams Village       1861              0
# 1  Addison Town and Village       2577              3
# 2             Akron Village       2846              3
# 3                    Albany      97956            791
# 4            Albion Village       6388             23
#
# 3 Murder and\nnonnegligent\nmanslaughter Rape\n(revised\ndefinition)1  \
# 0                                      0                          NaN
# 1                                      0                          NaN
# 2                                      0                          NaN
# 3                                      8                          NaN
# 4                                      0                          NaN
#
# 3 Rape\n(legacy\ndefinition)2 Robbery Aggravated\nassault Property\ncrime  \
# 0                           0       0                   0              12
# 1                           0       0                   3              24
# 2                           0       0                   3              16
# 3                          30     227                 526            4090
# 4                           3       4                  16             223
#
# 3 Burglary Larceny-\ntheft Motor\nvehicle\ntheft Arson3 Population_Squared
# 0        2              10                     0      0            3463321
# 1        3              20                     1      0            6640929
# 2        1              15                     0      0            8099716
# 3      705            3243                   142    NaN         9595377936
# 4       53             165                     5    NaN           40806544

# %%
nyc_crime['Murder'] = np.where(nyc_crime['Murder and\nnonnegligent\nmanslaughter'] > 0, 1, 0)

# %%
nyc_crime.head()
# Out:
# 3                      City Population Violent\ncrime  \
# 0             Adams Village       1861              0
# 1  Addison Town and Village       2577              3
# 2             Akron Village       2846              3
# 3                    Albany      97956            791
# 4            Albion Village       6388             23
#
# 3 Murder and\nnonnegligent\nmanslaughter Rape\n(revised\ndefinition)1  \
# 0                                      0                          NaN
# 1                                      0                          NaN
# 2                                      0                          NaN
# 3                                      8                          NaN
# 4                                      0                          NaN
#
# 3 Rape\n(legacy\ndefinition)2 Robbery Aggravated\nassault Property\ncrime  \
# 0                           0       0                   0              12
# 1                           0       0                   3              24
# 2                           0       0                   3              16
# 3                          30     227                 526            4090
# 4                           3       4                  16             223
#
# 3 Burglary Larceny-\ntheft Motor\nvehicle\ntheft Arson3 Population_Squared  \
# 0        2              10                     0      0            3463321
# 1        3              20                     1      0            6640929
# 2        1              15                     0      0            8099716
# 3      705            3243                   142    NaN         9595377936
# 4       53             165                     5    NaN           40806544
#
# 3  Murder
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0

# %%
nyc_crime['Robbery2'] = np.where(nyc_crime['Robbery'] > 0, 1, 0)

# %%
nyc_crime.head()
# Out:
# 3                      City Population Violent\ncrime  \
# 0             Adams Village       1861              0
# 1  Addison Town and Village       2577              3
# 2             Akron Village       2846              3
# 3                    Albany      97956            791
# 4            Albion Village       6388             23
#
# 3 Murder and\nnonnegligent\nmanslaughter Rape\n(revised\ndefinition)1  \
# 0                                      0                          NaN
# 1                                      0                          NaN
# 2                                      0                          NaN
# 3                                      8                          NaN
# 4                                      0                          NaN
#
# 3 Rape\n(legacy\ndefinition)2 Robbery Aggravated\nassault Property\ncrime  \
# 0                           0       0                   0              12
# 1                           0       0                   3              24
# 2                           0       0                   3              16
# 3                          30     227                 526            4090
# 4                           3       4                  16             223
#
# 3 Burglary Larceny-\ntheft Motor\nvehicle\ntheft Arson3 Population_Squared  \
# 0        2              10                     0      0            3463321
# 1        3              20                     1      0            6640929
# 2        1              15                     0      0            8099716
# 3      705            3243                   142    NaN         9595377936
# 4       53             165                     5    NaN           40806544
#
# 3  Murder  Robbery2
# 0       0         0
# 1       0         0
# 2       0         0
# 3       1         1
# 4       0         1

# %%
nyc_crime = nyc_crime[['City','Population','Population_Squared', 'Murder','Robbery2']]

# %%
nyc_crime.head()
# Out:
# 3                      City Population Population_Squared  Murder  Robbery2
# 0             Adams Village       1861            3463321       0         0
# 1  Addison Town and Village       2577            6640929       0         0
# 2             Akron Village       2846            8099716       0         0
# 3                    Albany      97956         9595377936       1         1
# 4            Albion Village       6388           40806544       0         1
